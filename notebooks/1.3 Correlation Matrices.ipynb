# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the aggregated data
csv_file_path = 'C:/Proyectos/Elecciones-2024/data/Agregados/Presidencial/TODO_pres_Seccion_aggregated.csv' 
aggregated_data = pd.read_csv(csv_file_path)

# Select the columns of interest
columns_of_interest = ['MORENA_COALITION_PERCENTAGE', 'OPPOSITION_COALITION_PERCENTAGE', 'OTHERS_PERCENTAGE', 'PARTICIPATION_PERCENTAGE']

# Calculate the correlation matrix
correlation_matrix = aggregated_data[columns_of_interest].corr()

# Plot the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, linewidths=.5, annot_kws={"size": 12})
plt.title('Correlation Matrix of Vote Percentages and Participation Percentage')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.tight_layout()

# Ensure the plots directory exists
plots_dir = 'C:/Proyectos/Elecciones-2024/plots'
os.makedirs(plots_dir, exist_ok=True)

# Save the correlation plot
correlation_plot_path = os.path.join(plots_dir, 'Correlation_Matrix.png')
plt.savefig(correlation_plot_path, dpi=300, bbox_inches='tight')
plt.close()

print(f'Saved correlation plot at {correlation_plot_path}')
# Out:
# Saved correlation plot at C:/Proyectos/Elecciones-2024/plots\Correlation_Matrix.png

# %%
sns.pairplot(aggregated_data[columns_of_interest])

# %%
sns.pairplot(aggregated_data[columns_of_interest], kind = "kde")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sns.pairplot(aggregated_data[columns_of_interest], kind = "kde")
#
# File ~\anaconda3\envs\mexico_elections_2024\Lib\site-packages\seaborn\axisgrid.py:2170, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2168     from .distributions import kdeplot  # Avoid circular import
#    2169     plot_kws.setdefault("warn_singular", False)
# -> 2170     plotter(kdeplot, **plot_kws)
#    2171 elif kind == "hist":
#    2172     from .distributions import histplot  # Avoid circular import
#
# File ~\anaconda3\envs\mexico_elections_2024\Lib\site-packages\seaborn\axisgrid.py:1425, in PairGrid.map_offdiag(self, func, **kwargs)
#    1414 """Plot with a bivariate function on the off-diagonal subplots.
# ...

# %%
sns.pairplot(aggregated_data[columns_of_interest],
             plot_kws=dict(marker="+", linewidth=1),
             diag_kws=dict(fill=False),)
